# %% [markdown]
# N-BaIoT with PCA same code as the last one

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tables import file
from pandas.core.indexes.multi import F
import pandas as pd

file1 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.benign.csv')
file1['label'] = 'benign'
file2 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.gafgyt.combo.csv')
file2['label'] = 'gafgyt combo'
file3 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.gafgyt.junk.csv')
file3['label'] = 'gafgyt junk'
file4 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.gafgyt.scan.csv')
file4['label'] = 'gafgyt scan'
file5 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.gafgyt.tcp.csv')
file5['label'] = 'gafgyt tcp'
file6 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.gafgyt.udp.csv')
file6['label'] = 'gafgyt udp'
file7 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.mirai.ack.csv')
file7['label'] = 'mirai ack'
file8 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.mirai.scan.csv')
file8['label'] = 'mirai scan'
file9 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.mirai.syn.csv')
file9['label'] = 'mirai syn'
file10 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.mirai.udp.csv')
file10['label'] = 'mirai udp'
file11 = pd.read_csv('/content/drive/MyDrive/archive (1)/1/1.mirai.udpplain.csv')
file11['label'] = 'mirai udpplain'
file12 = pd.read_csv('/content/drive/MyDrive/archive (1)/3/3.benign.csv')
file12['label'] = 'benign'
file13 = pd.read_csv('/content/drive/MyDrive/archive (1)/3/3.gafgyt.combo.csv')
file13['label'] = 'gafgyt combo'
file14 = pd.read_csv('/content/drive/MyDrive/archive (1)/3/3.gafgyt.junk.csv')
file14['label'] = 'gafgyt junk'
file15 = pd.read_csv('/content/drive/MyDrive/archive (1)/3/3.gafgyt.scan.csv')
file15['label'] = 'gafgyt scan'
file16 = pd.read_csv('/content/drive/MyDrive/archive (1)/3/3.gafgyt.tcp.csv')
file16['label'] = 'gafgyt tcp'
file17 = pd.read_csv('/content/drive/MyDrive/archive (1)/3/3.gafgyt.udp.csv')
file17['label'] = 'gafgyt udp'



file0 = pd.concat([file1, file2])
del file1,file2
file0 = pd.concat([file0,file3])
del file3
file0 = pd.concat([file0,file4])
del file4
file0 = pd.concat([file0,file5])
del file5
file0 = pd.concat([file0,file6])
del file6
file0 = pd.concat([file0,file7])
del file7
file0 = pd.concat([file0,file8])
del file8
file0 = pd.concat([file0,file9])
del file9
file0 = pd.concat([file0,file10])
del file10
file0 = pd.concat([file0,file11])
del file11
file0 = pd.concat([file0,file12])
del file12
file0 = pd.concat([file0,file13])
del file13
file0 = pd.concat([file0,file14])
del file14
file0 = pd.concat([file0,file15])
del file15
file0 = pd.concat([file0,file16])
del file16
file0 = pd.concat([file0,file17])
del file17

# %%
file0
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 0               1.000000       60.000000            0.000000
# 1               1.000000      354.000000            0.000000
# 2               1.857879      360.458980           35.789338
# 3               1.000000      337.000000            0.000000
# 4               1.680223      172.140917        18487.448750
# ...                  ...             ...                 ...
# 103928          1.000000       60.000000            0.000000
# 103929          1.000000       60.000000            0.000000
# 103930          1.000000       60.000000            0.000000
# 103931          1.000000       60.000000            0.000000
# 103932          1.000000       60.000000            0.000000
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 0               1.000000       60.000000            0.000000
# 1               1.000000      354.000000            0.000000
# 2               1.912127      360.275733           35.923972
# 3               1.000000      337.000000            0.000000
# 4               1.793580      182.560279        18928.175300
# ...                  ...             ...                 ...
# 103928          1.000000       60.000000            0.000000
# 103929          1.000000       60.000000            0.000000
# 103930          1.000000       60.000000            0.000000
# 103931          1.000000       60.000000            0.000000
# 103932          1.000000       60.000000            0.000000
#
#         MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 0               1.000000       60.000000            0.000000
# 1               1.000000      354.000000            0.000000
# 2               1.969807      360.091968           35.991542
# 3               1.000000      337.000000            0.000000
# 4               1.925828      193.165753        19153.795810
# ...                  ...             ...                 ...
# 103928          1.000000       60.000000            0.000000
# 103929          1.000000       60.000000            0.000000
# 103930          1.000000       60.000000            0.000000
# 103931          1.000000       60.000000            0.000000
# 103932          1.000000       60.000000            0.000000
#
#         MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  HpHp_L0.1_pcc  \
# 0                 1.000000  ...                   0.0            0.0
# 1                 1.000000  ...                   0.0            0.0
# 2                 1.996939  ...                   0.0            0.0
# 3                 1.000000  ...                   0.0            0.0
# 4                 1.992323  ...                   0.0            0.0
# ...                    ...  ...                   ...            ...
# 103928            1.000000  ...                   0.0            0.0
# 103929            1.000000  ...                   0.0            0.0
# 103930            1.000000  ...                   0.0            0.0
# 103931            1.000000  ...                   0.0            0.0
# 103932            1.000000  ...                   0.0            0.0
#
#         HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0                1.000000        60.000000        0.000000
# 1                5.319895       344.262695        4.710446
# 2                6.318264       347.703087        9.034660
# 3                1.000000       337.000000        0.000000
# 4                1.000000        60.000000        0.000000
# ...                   ...              ...             ...
# 103928           1.000000        60.000000        0.000000
# 103929           1.000000        60.000000        0.000000
# 103930           1.000000        60.000000        0.000000
# 103931           1.000000        60.000000        0.000000
# 103932           1.000000        60.000000        0.000000
#
#         HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0                  60.000000           0.000000                    0.0
# 1                 344.262695          22.188299                    0.0
# 2                 347.703087          81.625077                    0.0
# 3                 337.000000           0.000000                    0.0
# 4                  60.000000           0.000000                    0.0
# ...                      ...                ...                    ...
# 103928             60.000000           0.000000                    0.0
# 103929             60.000000           0.000000                    0.0
# 103930             60.000000           0.000000                    0.0
# 103931             60.000000           0.000000                    0.0
# 103932             60.000000           0.000000                    0.0
#
#         HpHp_L0.01_pcc       label
# 0                  0.0      benign
# 1                  0.0      benign
# 2                  0.0      benign
# 3                  0.0      benign
# 4                  0.0      benign
# ...                ...         ...
# 103928             0.0  gafgyt udp
# 103929             0.0  gafgyt udp
# 103930             0.0  gafgyt udp
# 103931             0.0  gafgyt udp
# 103932             0.0  gafgyt udp
#
# [1373798 rows x 116 columns]

# %%
file0['label'].value_counts()
# Out:
# mirai udp         237665
# gafgyt udp        209807
# gafgyt tcp        193677
# mirai syn         122573
# gafgyt combo      112732
# mirai scan        107685
# mirai ack         102195
# benign             88648
# mirai udpplain     81982
# gafgyt junk        58865
# gafgyt scan        57969
# Name: label, dtype: int64

# %%
#label encoding and standard scaler

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
file0.label = le.fit_transform(file0.label)

file0
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 0               1.000000       60.000000            0.000000
# 1               1.000000      354.000000            0.000000
# 2               1.857879      360.458980           35.789338
# 3               1.000000      337.000000            0.000000
# 4               1.680223      172.140917        18487.448750
# ...                  ...             ...                 ...
# 103928          1.000000       60.000000            0.000000
# 103929          1.000000       60.000000            0.000000
# 103930          1.000000       60.000000            0.000000
# 103931          1.000000       60.000000            0.000000
# 103932          1.000000       60.000000            0.000000
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 0               1.000000       60.000000            0.000000
# 1               1.000000      354.000000            0.000000
# 2               1.912127      360.275733           35.923972
# 3               1.000000      337.000000            0.000000
# 4               1.793580      182.560279        18928.175300
# ...                  ...             ...                 ...
# 103928          1.000000       60.000000            0.000000
# 103929          1.000000       60.000000            0.000000
# 103930          1.000000       60.000000            0.000000
# 103931          1.000000       60.000000            0.000000
# 103932          1.000000       60.000000            0.000000
#
#         MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 0               1.000000       60.000000            0.000000
# 1               1.000000      354.000000            0.000000
# 2               1.969807      360.091968           35.991542
# 3               1.000000      337.000000            0.000000
# 4               1.925828      193.165753        19153.795810
# ...                  ...             ...                 ...
# 103928          1.000000       60.000000            0.000000
# 103929          1.000000       60.000000            0.000000
# 103930          1.000000       60.000000            0.000000
# 103931          1.000000       60.000000            0.000000
# 103932          1.000000       60.000000            0.000000
#
#         MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  HpHp_L0.1_pcc  \
# 0                 1.000000  ...                   0.0            0.0
# 1                 1.000000  ...                   0.0            0.0
# 2                 1.996939  ...                   0.0            0.0
# 3                 1.000000  ...                   0.0            0.0
# 4                 1.992323  ...                   0.0            0.0
# ...                    ...  ...                   ...            ...
# 103928            1.000000  ...                   0.0            0.0
# 103929            1.000000  ...                   0.0            0.0
# 103930            1.000000  ...                   0.0            0.0
# 103931            1.000000  ...                   0.0            0.0
# 103932            1.000000  ...                   0.0            0.0
#
#         HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0                1.000000        60.000000        0.000000
# 1                5.319895       344.262695        4.710446
# 2                6.318264       347.703087        9.034660
# 3                1.000000       337.000000        0.000000
# 4                1.000000        60.000000        0.000000
# ...                   ...              ...             ...
# 103928           1.000000        60.000000        0.000000
# 103929           1.000000        60.000000        0.000000
# 103930           1.000000        60.000000        0.000000
# 103931           1.000000        60.000000        0.000000
# 103932           1.000000        60.000000        0.000000
#
#         HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0                  60.000000           0.000000                    0.0
# 1                 344.262695          22.188299                    0.0
# 2                 347.703087          81.625077                    0.0
# 3                 337.000000           0.000000                    0.0
# 4                  60.000000           0.000000                    0.0
# ...                      ...                ...                    ...
# 103928             60.000000           0.000000                    0.0
# 103929             60.000000           0.000000                    0.0
# 103930             60.000000           0.000000                    0.0
# 103931             60.000000           0.000000                    0.0
# 103932             60.000000           0.000000                    0.0
#
#         HpHp_L0.01_pcc  label
# 0                  0.0      0
# 1                  0.0      0
# 2                  0.0      0
# 3                  0.0      0
# 4                  0.0      0
# ...                ...    ...
# 103928             0.0      5
# 103929             0.0      5
# 103930             0.0      5
# 103931             0.0      5
# 103932             0.0      5
#
# [1373798 rows x 116 columns]

# %%
import numpy as np

# assume your DataFrame is named 'df'
file0 = file0.replace([np.inf, -np.inf], np.nan)  # replace infinite values with NaN
#da = da[da.abs() < np.finfo(np.float64).max]  # remove all rows containing values larger than max float

file0 = file0.dropna()

# print the new DataFrame shape to verify the infinite or too large values have been removed
print(file0.shape)
# Out:
# (1373798, 116)

# %%
 data = file0.iloc[:,:-1]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_features = scaler.fit_transform(file0.iloc[:,:-1])

# %%
scaled_features
# Out:
# array([[-1.16174857, -0.66373149, -0.62869419, ..., -0.01649825,
#         -0.01221603,  0.05986818],
#        [-1.16174857,  1.28266277, -0.62869419, ..., -0.01076399,
#         -0.01221603,  0.05986818],
#        [-1.14934825,  1.32542373, -0.62716065, ...,  0.00459664,
#         -0.01221603,  0.05986818],
#        ...,
#        [-1.16174857, -0.66373149, -0.62869419, ..., -0.01649825,
#         -0.01221603,  0.05986818],
#        [-1.16174857, -0.66373149, -0.62869419, ..., -0.01649825,
#         -0.01221603,  0.05986818],
#        [-1.16174857, -0.66373149, -0.62869419, ..., -0.01649825,
#         -0.01221603,  0.05986818]])

# %%
X = pd.DataFrame(scaled_features, columns = data.columns)
y = file0.iloc[:,-1]

print(X.shape)
print(y.shape)
# Out:
# (1373798, 115)
# (1373798,)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

subset1 = X.iloc[:, 0:20]
subset2 = X.iloc[:, 20:40]
subset3 = X.iloc[:, 40:60]
subset4 = X.iloc[:, 60:80]
subset5 = X.iloc[:, 80:100]
subset6 = X.iloc[:, 100:115]

corr_matrix1 = subset1.corr()
corr_matrix2 = subset2.corr()
corr_matrix3 = subset3.corr()
corr_matrix4 = subset4.corr()
corr_matrix5 = subset5.corr()
corr_matrix6 = subset6.corr()

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(30,10))
sns.heatmap(corr_matrix1, ax=ax[0][0], cmap="coolwarm", center=0)
sns.heatmap(corr_matrix2, ax=ax[0][1], cmap="coolwarm", center=0)
sns.heatmap(corr_matrix3, ax=ax[0][2], cmap="coolwarm", center=0)
sns.heatmap(corr_matrix4, ax=ax[1][0], cmap="coolwarm", center=0)
sns.heatmap(corr_matrix5, ax=ax[1][1], cmap="coolwarm", center=0)
sns.heatmap(corr_matrix6, ax=ax[1][2], cmap="coolwarm", center=0)

plt.show()

# %%
def correlation(dataset, threshold):
  col_corr = set()
  corr_matrix = dataset.corr()
  for i in range(len(corr_matrix.columns)):
    for j in range(i):
      if abs(corr_matrix.iloc[i, j]) > threshold:
        colname = corr_matrix.columns[i]
        col_corr.add(colname)
  return col_corr

# %%
corr_features = correlation(X_train,0.8)
len(set(corr_features))
# Out:
# 87

# %%
corr_features
# Out:
# {'HH_L0.01_magnitude',
#  'HH_L0.01_mean',
#  'HH_L0.01_radius',
#  'HH_L0.01_std',
#  'HH_L0.01_weight',
#  'HH_L0.1_magnitude',
#  'HH_L0.1_mean',
#  'HH_L0.1_weight',
#  'HH_L1_covariance',
#  'HH_L1_magnitude',
#  'HH_L1_mean',
#  'HH_L1_radius',
#  'HH_L1_std',
#  'HH_L1_weight',
#  'HH_L3_covariance',
#  'HH_L3_magnitude',
#  'HH_L3_mean',
#  'HH_L3_pcc',
#  'HH_L3_radius',
#  'HH_L3_std',
#  'HH_L3_weight',
#  'HH_L5_magnitude',
#  'HH_jit_L0.01_mean',
#  'HH_jit_L0.01_variance',
#  'HH_jit_L0.01_weight',
#  'HH_jit_L0.1_mean',
#  'HH_jit_L0.1_weight',
#  'HH_jit_L1_mean',
#  'HH_jit_L1_weight',
#  'HH_jit_L3_mean',
#  'HH_jit_L3_variance',
#  'HH_jit_L3_weight',
#  'HH_jit_L5_weight',
#  'H_L0.01_mean',
#  'H_L0.01_variance',
#  'H_L0.01_weight',
#  'H_L0.1_mean',
#  'H_L0.1_variance',
#  'H_L0.1_weight',
#  'H_L1_mean',
#  'H_L1_variance',
#  'H_L1_weight',
#  'H_L3_mean',
#  'H_L3_variance',
#  'H_L3_weight',
#  'H_L5_mean',
#  'H_L5_variance',
#  'H_L5_weight',
#  'HpHp_L0.01_covariance',
#  'HpHp_L0.01_magnitude',
#  'HpHp_L0.01_mean',
#  'HpHp_L0.01_radius',
#  'HpHp_L0.01_std',
#  'HpHp_L0.01_weight',
#  'HpHp_L0.1_covariance',
#  'HpHp_L0.1_magnitude',
#  'HpHp_L0.1_mean',
#  'HpHp_L0.1_pcc',
#  'HpHp_L0.1_weight',
#  'HpHp_L1_covariance',
#  'HpHp_L1_magnitude',
#  'HpHp_L1_mean',
#  'HpHp_L1_radius',
#  'HpHp_L1_std',
#  'HpHp_L1_weight',
#  'HpHp_L3_covariance',
#  'HpHp_L3_magnitude',
#  'HpHp_L3_mean',
#  'HpHp_L3_pcc',
#  'HpHp_L3_radius',
#  'HpHp_L3_std',
#  'HpHp_L3_weight',
#  'HpHp_L5_covariance',
#  'HpHp_L5_magnitude',
#  'HpHp_L5_mean',
#  'HpHp_L5_radius',
#  'MI_dir_L0.01_mean',
#  'MI_dir_L0.01_variance',
#  'MI_dir_L0.1_mean',
#  'MI_dir_L0.1_variance',
#  'MI_dir_L0.1_weight',
#  'MI_dir_L1_mean',
#  'MI_dir_L1_variance',
#  'MI_dir_L1_weight',
#  'MI_dir_L3_mean',
#  'MI_dir_L3_variance',
#  'MI_dir_L3_weight'}

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=100)
Xrus,Yrus = rus.fit_resample(X,y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(Xrus,Yrus, test_size=0.2, random_state=100)

X_train.shape

y_train.shape
# Out:
# (510127,)

# %%
X_train.shape
# Out:
# (510127, 115)

# %%
X_train = X_train.drop(corr_features,axis = 1)
X_test = X_test.drop(corr_features, axis = 1)

# %%
from sklearn.feature_selection import SelectKBest, f_classif

k = 10

selector = SelectKBest(f_classif, k=k) 
selector.fit(X_train, y_train)

selected_indices = selector.get_support(indices=True)
selected_features = X_train.columns[selected_indices]

scores = selector.scores_
plt.bar(range(len(scores)), scores)
plt.xlabel('Feature Index')
plt.ylabel('F-Score')
plt.show()

top_scores = sorted(scores, reverse=True)[:k]
top_indices = [list(scores).index(score) for score in top_scores]
top_features = X_train.columns[top_indices]
plt.bar(range(k), top_scores)
plt.xticks(range(k), top_features, rotation=90)
plt.xlabel('Feature')
plt.ylabel('F-Score')
plt.show()

# %%
best_table = pd.DataFrame({'Feature': top_features , 'Importance': top_scores })
print(best_table)
# Out:
#                 Feature     Importance
# 0    MI_dir_L5_variance  360962.502796
# 1      MI_dir_L5_weight  307786.302217
# 2        MI_dir_L5_mean  293892.823858
# 3          HH_L5_weight  251046.980941
# 4   MI_dir_L0.01_weight  183331.858855
# 5  HH_jit_L0.1_variance   70750.008270
# 6        HH_jit_L5_mean   69624.724795
# 7            HH_L5_mean   57312.623985
# 8        HpHp_L5_weight   53479.550576
# 9    HH_jit_L1_variance   19414.076462

# %%
# Running Machine Learning Models

#1. Naive Bayes
import time

from sklearn.naive_bayes import BernoulliNB

ml1 = BernoulliNB()

start_ttime = time.time()

ml1.fit(X_train, y_train)

end_ttime = time.time()

train_time = end_ttime - start_ttime

ml1.score(X_train,y_train)

ml1.score(X_test,y_test)

start_time = time.time()

y_pred_nb = ml1.predict(X_test)

end_time = time.time()

test_time = end_time - start_time

print("TT", test_time)

print("TT1", train_time)
from sklearn.metrics import classification_report, accuracy_score

print("Accuracy Score : {:.3f}".format(accuracy_score(y_test, y_pred_nb)))
print("\nClassification Report :")
print(classification_report(y_test, y_pred_nb))

import sklearn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred_nb)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

from sklearn.metrics import log_loss

y_pred_proba = ml1.predict_proba(X_test)
logloss = log_loss(y_test, y_pred_proba)
print(logloss)
# Out:
# TT 0.1604321002960205
# TT1 1.013505458831787
# Accuracy Score : 0.552
#
# Classification Report :
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.95      0.56      0.70     11676
#            1       0.43      0.60      0.50     11464
#            2       0.62      0.79      0.69     11623
#            3       0.59      0.64      0.61     11520
#            4       0.00      0.00      0.00     11675
#            5       0.40      1.00      0.57     11528
#            6       0.38      0.41      0.39     11597
#            7       0.68      0.78      0.73     11576
#            8       0.88      0.00      0.00     11673
#            9       0.53      0.61      0.56     11578
#           10       0.89      0.69      0.78     11622
#
#     accuracy                           0.55    127532
#    macro avg       0.58      0.55      0.50    127532
# weighted avg       0.58      0.55      0.50    127532
# 0.9084911788239806

# %%
from sklearn.metrics import precision_score
macro_score_rf = precision_score(y_test,y_pred_nb,average='macro')
micro_score_rf = precision_score(y_test,y_pred_nb,average='micro')
weighted_score_rf = precision_score(y_test,y_pred_nb,average='weighted')

#precision scores
print(macro_score_rf)
print(micro_score_rf)
print(weighted_score_rf)

from sklearn.metrics import recall_score
rmacro_score_rf = recall_score(y_test,y_pred_nb,average='macro')
rmicro_score_rf = recall_score(y_test,y_pred_nb,average='micro')
rweighted_score_rf = recall_score(y_test,y_pred_nb,average='weighted')

#precision scores
print(rmacro_score_rf)
print(rmicro_score_rf)
print(rweighted_score_rf)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.5765575945862564
# 0.552363328419534
# 0.576923320133565
# 0.5533442512671425
# 0.552363328419534
# 0.552363328419534

# %%
from sklearn.tree import DecisionTreeClassifier

ml2 = DecisionTreeClassifier(random_state=100)

start_ttime = time.time()

ml2.fit(X_train, y_train)

end_ttime = time.time()

train_time = end_ttime - start_ttime


print(ml2.score(X_train,y_train))
print(ml2.score(X_test,y_test))

start_time = time.time()

y_pred_dt = ml2.predict(X_test)


end_time = time.time()

test_time = end_time - start_time

print("TT", test_time)

print("TT1", train_time)

print("Accuracy Score : {:.3f}".format(accuracy_score(y_test, y_pred_dt)))
print("\nClassification Report :")
print(classification_report(y_test, y_pred_dt))

cm = confusion_matrix(y_test, y_pred_dt)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

y_pred_proba = ml2.predict_proba(X_test)
logloss = log_loss(y_test, y_pred_proba)
print(logloss)
# Out:
# 0.9093421834170706
# 0.9083210488348022
# TT 0.022287607192993164
# TT1 7.049462795257568
# Accuracy Score : 0.908
#
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11676
#            1       1.00      1.00      1.00     11464
#            2       1.00      1.00      1.00     11623
#            3       1.00      1.00      1.00     11520
#            4       1.00      0.00      0.00     11675
#            5       0.50      1.00      0.66     11528
#            6       1.00      1.00      1.00     11597
#            7       1.00      1.00      1.00     11576
#            8       1.00      1.00      1.00     11673
#            9       1.00      1.00      1.00     11578
#           10       1.00      1.00      1.00     11622
#
#     accuracy                           0.91    127532
#    macro avg       0.95      0.91      0.88    127532
# weighted avg       0.95      0.91      0.88    127532
# 0.1327323179602537

# %%
from sklearn.metrics import precision_score
macro_score_rf = precision_score(y_test,y_pred_dt,average='macro')
micro_score_rf = precision_score(y_test,y_pred_dt,average='micro')
weighted_score_rf = precision_score(y_test,y_pred_dt,average='weighted')

#precision scores
print(macro_score_rf)
print(micro_score_rf)
print(weighted_score_rf)

from sklearn.metrics import recall_score
rmacro_score_rf = recall_score(y_test,y_pred_dt,average='macro')
rmicro_score_rf = recall_score(y_test,y_pred_dt,average='micro')
rweighted_score_rf = recall_score(y_test,y_pred_dt,average='weighted')

#precision scores
print(rmacro_score_rf)
print(rmicro_score_rf)
print(rweighted_score_rf)
# Out:
# 0.9540829396994954
# 0.9083210488348022
# 0.9543426008924136
# 0.9089561406420515
# 0.9083210488348022
# 0.9083210488348022

# %%
from sklearn.tree import ExtraTreeClassifier

ml3 = ExtraTreeClassifier(random_state=100)

start_ttime = time.time()

ml3.fit(X_train, y_train)

end_ttime = time.time()

train_time = end_ttime - start_ttime


print(ml3.score(X_train,y_train))
print(ml3.score(X_test,y_test))

start_time = time.time()

y_pred_et = ml3.predict(X_test)

end_time = time.time()

test_time = end_time - start_time

print("TT", test_time)
print("TT1", train_time)
print("Accuracy Score : {:.3f}".format(accuracy_score(y_test, y_pred_et)))
print("\nClassification Report :")
print(classification_report(y_test, y_pred_et))

cm = confusion_matrix(y_test, y_pred_et)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

y_pred_proba = ml3.predict_proba(X_test)
logloss = log_loss(y_test, y_pred_proba)
print(logloss)
# Out:
# 1.0
# 0.9991688360568328
# TT 0.029078006744384766
# TT1 0.8637475967407227
# Accuracy Score : 0.999
#
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11676
#            1       1.00      1.00      1.00     11464
#            2       1.00      1.00      1.00     11623
#            3       1.00      1.00      1.00     11520
#            4       1.00      1.00      1.00     11675
#            5       1.00      1.00      1.00     11528
#            6       1.00      1.00      1.00     11597
#            7       1.00      1.00      1.00     11576
#            8       1.00      1.00      1.00     11673
#            9       1.00      1.00      1.00     11578
#           10       1.00      1.00      1.00     11622
#
#     accuracy                           1.00    127532
#    macro avg       1.00      1.00      1.00    127532
# weighted avg       1.00      1.00      1.00    127532
# 0.02995818507705282

# %%
from sklearn.metrics import precision_score
macro_score_rf = precision_score(y_test,y_pred_et,average='macro')
micro_score_rf = precision_score(y_test,y_pred_et,average='micro')
weighted_score_rf = precision_score(y_test,y_pred_et,average='weighted')

#precision scores
print(macro_score_rf)
print(micro_score_rf)
print(weighted_score_rf)

from sklearn.metrics import recall_score
rmacro_score_rf = recall_score(y_test,y_pred_et,average='macro')
rmicro_score_rf = recall_score(y_test,y_pred_et,average='micro')
rweighted_score_rf = recall_score(y_test,y_pred_et,average='weighted')

#precision scores
print(rmacro_score_rf)
print(rmicro_score_rf)
print(rweighted_score_rf)
# Out:
# 0.9991691632508372
# 0.9991688360568328
# 0.9991691590695648
# 0.9991654721710941
# 0.9991688360568328
# 0.9991688360568328

# %%
'''from sklearn.neighbors import KNeighborsClassifier

ml4 = KNeighborsClassifier(n_neighbors= 1000)

ml4.fit(X_train,y_train)

#print(ml4.score(X_train,y_train))
#print(ml4.score(X,y))

y_pred = ml4.predict(X)

from sklearn.metrics import classification_report, accuracy_score

print("Accuracy Score : {:.3f}".format(accuracy_score(y, y_pred)))
print("\nClassification Report :")
print(classification_report(y, y_pred))

import sklearn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

cm = confusion_matrix(y, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

from sklearn.metrics import log_loss

y_pred_proba = ml4.predict_proba(X)
logloss = log_loss(y, y_pred_proba)
print(logloss)'''

# %%
from sklearn.ensemble import RandomForestClassifier

ml6 = RandomForestClassifier(random_state=100)

start_ttime = time.time()

ml6.fit(X_train, y_train)

end_ttime = time.time()

train_time = end_ttime - start_ttime

print(ml6.score(X_train,y_train))
print(ml6.score(X_test,y_test))

start_time = time.time()

y_pred = ml6.predict(X_test)


end_time = time.time()

test_time = end_time - start_time

print("TT", test_time)

print("TT1", train_time)

from sklearn.metrics import classification_report, accuracy_score

print("Accuracy Score : {:.3f}".format(accuracy_score(y_test, y_pred)))
print("\nClassification Report :")
print(classification_report(y_test, y_pred))

import sklearn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

from sklearn.metrics import log_loss

y_pred_proba = ml6.predict_proba(X_test)
logloss = log_loss(y_test, y_pred_proba)
print(logloss)
# Out:
# 0.9093421834170706
# 0.9084151428661041
# TT 2.7253429889678955
# TT1 133.1654772758484
# Accuracy Score : 0.908
#
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     11676
#            1       1.00      1.00      1.00     11464
#            2       1.00      1.00      1.00     11623
#            3       1.00      1.00      1.00     11520
#            4       0.88      0.00      0.00     11675
#            5       0.50      1.00      0.66     11528
#            6       1.00      1.00      1.00     11597
#            7       1.00      1.00      1.00     11576
#            8       1.00      1.00      1.00     11673
#            9       1.00      1.00      1.00     11578
#           10       1.00      1.00      1.00     11622
#
#     accuracy                           0.91    127532
#    macro avg       0.94      0.91      0.88    127532
# weighted avg       0.94      0.91      0.88    127532
# 0.14345190843060515

# %%
ml6.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 100,
#  'verbose': 0,
#  'warm_start': False}

# %%
importances = ml6.feature_importances_

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,6))
plt.title("Feature Importances")
plt.bar(range(X_train.shape[1]), importances[indices])
plt.xticks(range(X_train.shape[1]), X_train.columns[indices], rotation=90)
plt.show()

# show table of top feature importance values
importance_table = pd.DataFrame({'Feature': X_test.columns[indices], 'Importance': importances[indices]})
print(importance_table.head(10))
# Out:
#                 Feature  Importance
# 0   MI_dir_L0.01_weight    0.168956
# 1        MI_dir_L5_mean    0.150200
# 2        HH_jit_L5_mean    0.124231
# 3      MI_dir_L5_weight    0.095467
# 4            HH_L5_mean    0.092691
# 5          HH_L5_weight    0.083569
# 6    MI_dir_L5_variance    0.076223
# 7  HH_jit_L0.1_variance    0.053095
# 8           HH_L0.1_std    0.030549
# 9        HH_L0.1_radius    0.028224

# %%
from sklearn.metrics import precision_score
macro_score_rf = precision_score(y,y_pred,average='macro')
micro_score_rf = precision_score(y,y_pred,average='micro')
weighted_score_rf = precision_score(y,y_pred,average='weighted')

#precision scores
print(macro_score_rf)
print(micro_score_rf)
print(weighted_score_rf)

from sklearn.metrics import recall_score
rmacro_score_rf = recall_score(y,y_pred,average='macro')
rmicro_score_rf = recall_score(y,y_pred,average='micro')
rweighted_score_rf = recall_score(y,y_pred,average='weighted')

#precision scores
print(rmacro_score_rf)
print(rmicro_score_rf)
print(rweighted_score_rf)
# Out:
# 0.9506861534927092
# 0.8591219378685949
# 0.917931340687655
# 0.9091535271379816
# 0.8591219378685949
# 0.8591219378685949
